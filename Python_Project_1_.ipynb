# %% [markdown]
# <a href="https://colab.research.google.com/github/sokelly1/Healthfirst--Data-analytics/blob/main/Python_Project_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %%
df.columns
# Out:
# Index(['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year',
#        'Total Tested', 'Mean Score', 'Number Scoring Below 65',
#        'Percent Scoring Below 65', 'Number Scoring 65 or Above',
#        'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
#        'Percent Scoring 80 or Above', 'Number Scoring CR',
#        'Percent Scoring CR'],
#       dtype='object')

# %%
df.head()
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#           Regents Exam  Year  Total Tested Mean Score Number Scoring Below 65  \
# 0  Common Core Algebra  2017             4          s                       s
# 1   Living Environment  2015            16       77.9                       1
# 2   Living Environment  2016             9         74                       1
# 3  Common Core Algebra  2016             3          s                       s
# 4  Common Core Algebra  2017             2          s                       s
#
#   Percent Scoring Below 65 Number Scoring 65 or Above  \
# 0                        s                          s
# ...

# %%
df.pivot_table(index='School Name', values='Regents Exam', aggfunc='count').sort_values('Regents Exam', ascending=False)
# Out:
#                                                     Regents Exam
# School Name
# New Visions Charter High School for Advanced Math           1337
# New Visions Charter High School for the Humanities          1031
# James Madison High School                                    490
# Francis Lewis High School                                    490
# Long Island City High School                                 489
# ...                                                          ...
# Success Academy Charter School - Harlem 3                      5
# P.S. 202 Ernest S. Jenkyns                                     5
# Explore Excel Charter School                                   5
# Community Math & Science Prep                                  5
# Academy for New Americans                                      5
#
# [1012 rows x 1 columns]

# %%
filtered_df=df2[df['School Name']=='James Madison High School']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-1d778068cf81> in <cell line: 0>()
# ----> 1 filtered_df=df2[df['School Name']=='James Madison High School']
#
# NameError: name 'df2' is not defined

# %%
filtered_df = df[df['School Name'] == 'James Madison High School']

# %%
filtered_df
# Out:
#        School DBN                School Name School Level  \
# 12927      22K425  James Madison High School  High school
# 12928      22K425  James Madison High School  High school
# 12929      22K425  James Madison High School  High school
# 12930      22K425  James Madison High School  High school
# 12931      22K425  James Madison High School  High school
# ...           ...                        ...          ...
# 187790     22K425  James Madison High School  High school
# 187791     22K425  James Madison High School  High school
# 187792     22K425  James Madison High School  High school
# 187793     22K425  James Madison High School  High school
# 187794     22K425  James Madison High School  High school
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 12927         Algebra2/Trigonometry  2015           434       67.3
# 12928         Algebra2/Trigonometry  2016           408       70.1
# ...

# %%
import matplotlib.pyplot as plt

# %%
filtered_df.drop_duplicates(inplace=True)
# Out:
# <ipython-input-37-9f835bf9b7bc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.drop_duplicates(inplace=True)

# %%
import matplotlib.pyplot as plt


x = filtered_df.groupby('Regents Exam')['Mean Score'].count().reset_index() # or .mean(), depending on what aggregation you intend

# create a bar chart of the number of exams per Regents Exam
plt.bar(x['Regents Exam'], x['Mean Score'])

# Set the title and labels for the chart
plt.title('Number of Exams per Regents Exam')
plt.xlabel('Regents Exam')
plt.ylabel('Number of Exams')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Display the chart
plt.show()
